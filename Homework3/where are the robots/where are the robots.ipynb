# %% [markdown]
# Hint: What part of the website could tell you where the creator doesn't want you to look?

# %% [markdown]
# This is the main page :
#
# ![image.png](attachment:image.png)
#
# According to previus exercices, we try to use the robots.txt link to get probably the key:
#
# and we get this view:
#
# ![image-2.png](attachment:image-2.png)
#
# it looks like its part of a URL, so we are going to reemplace it to the actual url
#
# And we found our flag
#
# ![image-3.png](attachment:image-3.png)
#
# picoCTF{ca1cu1at1ng_Mach1n3s_1bb4c}
