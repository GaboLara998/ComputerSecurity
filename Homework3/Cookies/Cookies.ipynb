# %% [markdown]
# Searching for 'snickerdoodle' as hint of the input text
#
#
# ![Screen1.png](data:image/png;base64,...)

# %% [markdown]
# If we try to enter another kind of value and we inspect the cookies from the page the see that it has a 'name' and a 'Value', and here it has a negative value, so it means in a correct input it has a positive value
#
# ![Screen2.png](data:image/png;base64,...)

# %% [markdown]
# Certainly at a correct input, the value is positive, so we start looking for different values, changing the number at 'Value'
#
# ![image.png](attachment:image.png)

# %% [markdown]
# After 18 attemps and reloadings we get this message:
#
# ![image.png](attachment:image.png)
#
#
# Our flag: picoCTF{3v3ry1_l0v3s_c00k135_94190c8a}
