# %% [markdown]
# ##Searching for 'snickerdoodle'
#
#
# ![Screen1.png](data:image/png;base64,...)

# %% [markdown]
# ##Searching for other input
#
# ![Screen2.png](data:image/png;base64,...)
#
#
# ##So
