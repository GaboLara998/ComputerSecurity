# %% [markdown]
# ### We log in into de page
#
# ![image-2.png](attachment:image-2.png)
#
# ### and we see the networking page at devtools at Chrome

# %% [markdown]
# ![image.png](attachment:image.png)
#
# there are 2 url's at the moment of login
#
# http://saturn.picoctf.net:56907/next-page/id=cGljb0NURntwcm94aWVzX2Fs
#
# and
#
# http://saturn.picoctf.net:56907/next-page/id=bF90aGVfd2F5X2EwZmUwNzRmfQ==
#
# it looks like base65 text

# %%
import base64

encoded_string = "cGljb0NURntwcm94aWVzX2FsbF90aGVfd2F5X2EwZmUwNzRmfQ=="
decoded_string = base64.b64decode(encoded_string).decode('utf-8')

print(decoded_string)
# Out:
# picoCTF{proxies_all_the_way_a0fe074f}
