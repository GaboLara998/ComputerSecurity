# %% [markdown]
# Hint 1: Look at the category of this problem.
#
# Hint 2: How may a PHP site check the rules in the description?

# %% [markdown]
# At the beginning we see this page:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Doing some research about md5 hash collisions values we found this
#
# " ![image.png](attachment:image.png)"
#
# From :
#
# " https://crypto.stackexchange.com/questions/1434/are-there-two-known-strings-which-have-the-same-md5-hash-value"

# %% [markdown]
# There are two programs that can simulate the sum using to different inputs or collisions using md5 hash function
#
# ![image.png](attachment:image.png)
#
#
# From: https://www.mscs.dal.ca/~selinger/md5collision/

# %% [markdown]
# This two programas
# 1. hello.exe
# 2. erase.exe
#
# are going to be uploaded to the inicial page, but before that we need to change the file extension of both files to .pdf, like this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now we see a index.php code
#
# ![image.png](attachment:image.png)
#
# So our flag is: picoCTF{c0ngr4ts_u_r_1nv1t3d_da36cc1b}
