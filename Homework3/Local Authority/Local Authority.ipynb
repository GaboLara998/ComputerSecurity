# %% [markdown]
# How is the password checked on this website?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# According to the hints we try to log in using "Username" and "Password"
#
# but we get an login error:
#
#
# ![image.png](attachment:image.png)
#
# so we start looking at the devtools from chrome

# %% [markdown]
# From Sources there is a file called secure.js with this code:
#
# ![image.png](attachment:image.png)
#
# So now we know the rigth credentials

# %% [markdown]
# Now we the login is succesfull, and the flag is shown
# ![image.png](attachment:image.png)

# %% [markdown]
# answer: picoCTF{j5_15_7r4n5p4r3n7_05df90c8}
