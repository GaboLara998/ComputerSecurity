# %% [markdown]
# Hint: How could you mirror the website on your local machine so you could use more powerful tools for searching?

# %% [markdown]
# Looking at the source code of the page, we found this message:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Lookin at each file we found the flag at the style.css
#
# ![image.png](attachment:image.png)
#
# So our flag is:
#
# picoCTF{1nsp3ti0n_0f_w3bpag3s_587d12b8}
