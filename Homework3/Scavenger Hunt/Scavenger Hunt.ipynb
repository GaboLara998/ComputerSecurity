# %% [markdown]
# ### Analyzing the website files we found the first clue as a comment. picoCTF{t

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The file mycss.css has the following message: /* CSS makes the page look nice, and yes, it also has part of the flag. Here's part 2: h4ts_4_l0 */
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The file myjs.js has the following message: /* How can I keep Google from indexing my website? */
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# #### Google keep track of websites using web crawling / spider engine, it has a special file called robots.txt.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# So we get this part: # Part 3: t_0f_pl4c
#
# and I think this is an apache server... can you Access the next flag? we do this by accessing .htaccess

# %% [markdown]
# ### http://mercury.picoctf.net:27393/.htaccess
#
# ### # Part 4: 3s_2_lO0k
# ####  I love making websites on my Mac, I can Store a lot of information there.
#
# ####  in macOS a DS.Store is a file that stores information about the current folder
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### http://mercury.picoctf.net:27393/.DS_Store
# ### we get the last message: Congrats! You completed the scavenger hunt. Part 5: _d375c750}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer: picoCTF{th4ts_4_l0t_0f_pl4c3s_2_lO0k_d375c750}
