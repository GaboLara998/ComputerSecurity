# %% [markdown]
# Hint: What is the web inspector in web browsers?

# %% [markdown]
# Can you get the flag?
# Go to this website and see what you can discover.
#
# This is the web
# ![image.png](attachment:image.png)

# %% [markdown]
# So we are going to look at the source code of the page and this is what we find:
#
# ![image.png](attachment:image.png)
#
#
# Here is our flag!
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# answer: picoCTF{1n5p3t0r_0f_h7ml_8113f7e2}
