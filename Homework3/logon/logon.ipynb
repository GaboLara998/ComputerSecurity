# %% [markdown]
# Hint: Hmm it doesn't seem to check anyone's password, except for Joe's?
#
# After trying to log in using admin as username and admin  as password webpage we get in this page:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Using devtoools to analize the cookies:
#
# ![image.png](attachment:image.png)
#
#
# After using different credentials to login the values kept the same
#
# ![image-2.png](attachment:image-2.png)
#
# it has a false value as admin cookie, but if we change this false admin value, to a true value, and now we refresh the page to get out flag
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# Flag:  picoCTF{th3_c0nsp1r4cy_l1v3s_0c98aacc}
